# %%
with open("finaldata.txt" ,encoding='utf-8') as f:
    data=f.read()

# %%
data
# Out:
# "techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes\n\nblrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes\n\nhsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com\n\ncloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud\n\nkoramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter\n\nai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & resea
# ...

# %%
chunks=data.split("\n\n")
chunks=[c for c in chunks if len(c)>3]
chunks
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes',
#  'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes',
#  'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com',
#  'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud',
#  'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter',
# ...

# %%
def parse_chunk(chunk):
    chunk=chunk.strip()
    sep_chunk=chunk.split('\n')
    username=sep_chunk[0]
    no_of_post=int(sep_chunk[1].split("post")[0].replace(",",""))
    no_of_follower=float(sep_chunk[2].split("follower")[0].replace(",","").replace("K","").replace("M",""))
    if("K" in sep_chunk[2]):
        no_of_follower=int(no_of_follower * 1000)
    elif("M" in sep_chunk[2]):
        no_of_follower=int(no_of_follower * 1000000)
    else:
        no_of_follower=int(no_of_follower)


    
    no_of_following=float(sep_chunk[3].split("following")[0].replace(",","").replace("K","").replace("M",""))
    if("K" in sep_chunk[3]):
        no_of_following=int(no_of_following *1000)
    elif("M" in sep_chunk[3]):
        no_of_following=int(no_of_following * 1000000)
    else:
        no_of_following=int(no_of_following)

    name=sep_chunk[4]
    if(len(sep_chunk)>5):
        type_of_page=sep_chunk[5]
        bio="\n".join(sep_chunk[6:])
    else:
        type_of_page="Unkown"
        bio=""

    return{"Username":username,"no_of_post":no_of_post ,"no_of_follower":no_of_follower,
          "no_of_following":no_of_following, "type_of_page":type_of_page , "Bio":bio}

# %%
all_chunks=[]
for chunk in chunks:
    parsed_chunk=parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
print(len(chunks))
# Out:
# [{'Username': 'techie_koramangala', 'no_of_post': 420, 'no_of_follower': 9800, 'no_of_following': 310, 'type_of_page': 'Software Engineer', 'Bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'Username': 'blrcoder_girl', 'no_of_post': 150, 'no_of_follower': 6300, 'no_of_following': 120, 'type_of_page': 'Tech Creator', 'Bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'Username': 'hsr_startup_stories', 'no_of_post': 980, 'no_of_follower': 22400, 'no_of_following': 95, 'type_of_page': 'Media', 'Bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'Username': 'cloud_dev_blr', 'no_of_post': 210, 'no_of_follower': 4500, 'no_of_following': 60, 'type_of_page': 'Engineer', 'Bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'}, {'Username': 'koramangala_coffee_lover', 'no_of_post': 300, 'no_of_follower': 7900, 'no_of_following': 180, '
# ...

# %%
import json
s=json.dumps(all_chunks , indent=4)
print(s)
# with open ("data.json", "w") as f:
#     f.write(s)
# Out:
# [
#     {
#         "Username": "techie_koramangala",
#         "no_of_post": 420,
#         "no_of_follower": 9800,
#         "no_of_following": 310,
#         "type_of_page": "Software Engineer",
#         "Bio": "\ud83d\udcbb Full-stack @ SaaS startup\n\u2615 Working from cafes in Koramangala\ngithub.com/arjunmakes"
#     },
#     {
#         "Username": "blrcoder_girl",
#         "no_of_post": 150,
#         "no_of_follower": 6300,
#         "no_of_following": 120,
#         "type_of_page": "Tech Creator",
#         "Bio": "\ud83d\udc69\u200d\ud83d\udcbb Python | ML | Roadmaps\n\ud83c\udfa5 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes"
#     },
#     {
#         "Username": "hsr_startup_stories",
#         "no_of_post": 980,
#         "no_of_follower": 22400,
#         "no_of_following": 95,
#         "type_of_page": "Media",
#         "Bio": "\ud83d\ude80 Interviews with Bangalore founders\n\ud83c\udf99\ufe0f Weekly startup breakdowns\nhsrstartupstories.com"
#     },
# ...

# %% [markdown]
# # Who has the maximum posts??
# lets write a code to find maximum post

# %%
max=0
for chunk in all_chunks:
    if(max <chunk['no_of_post']):
        max=chunk['no_of_post']
        chunk_with_max_post=chunk
print(chunk_with_max_post['Username'])
# Out:
# startuphub_blr

# %% [markdown]
# # Who follows maximum people??
# lets write a code to find a who follow maximum people

# %%
max=0
for chunk in all_chunks:
    if(max <chunk['no_of_follower']):
        max=chunk['no_of_follower']
        chunk_with_max_follower=chunk
print(chunk_with_max_follower)
# Out:
# {'Username': '_anujsinghal', 'no_of_post': 1785, 'no_of_follower': 681000, 'no_of_following': 248, 'type_of_page': 'Digital creator', 'Bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %% [markdown]
# # How many categories??
# lets write a code to find our number of categories

# %%
categories=set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(f"There are {len(categories)} categories")
print(categories)
# Out:
# There are 34 categories
# {'Investor', 'Software Engineer', 'Data Science', 'Cafe Explorer', 'Frontend Dev', 'Cafe Nerd', 'Product Manager', 'Design', 'Writer', 'Coder', 'Comedy', 'Digital creator', 'Blogger', 'Full-stack Dev', 'Recruiter', 'Media', 'Public Figure', 'Artist + Coder', 'Data Scientist', 'Food & Drink', 'Founder', 'Community', 'Personal Blog', 'Developer', 'Backend Developer', 'Nonprofit organization', 'Education', 'Entrepreneur', 'Educator', 'Engineer', 'Tech Creator', 'Blog', 'Tech', 'Lifestyle'}
